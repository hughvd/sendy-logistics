# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_pickle('clean_training.pkl')

# %%
df.dtypes
# Out:
# Rider_id           object
# No_Of_Orders        int64
# Age                 int64
# Average_Rating    float64
# No_of_Ratings       int64
# Platform_type       int64
# is_business          bool
# Pickup_weekday      int64
# Pickup_time         int64
# Distance            int64
# Temperature       float64
# Travel_time         int64
# dtype: object

# %%
df.No_Of_Orders.describe()
# Out:
# count    21201.000000
# mean      1692.423706
# std       1574.308302
# min          2.000000
# 25%        557.000000
# 50%       1212.000000
# 75%       2311.000000
# max       9756.000000
# Name: No_Of_Orders, dtype: float64

# %%
sns.displot(df.No_Of_Orders, bins=20, kde=False, rug=False)
# Out:
# C:\Users\joshu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.Age.describe()
# Out:
# count    21201.000000
# mean       984.742842
# std        646.652835
# min         96.000000
# 25%        495.000000
# 50%        872.000000
# 75%       1236.000000
# max       3764.000000
# Name: Age, dtype: float64

# %%
sns.displot(df.Age, bins=20, kde=False, rug=False)
# Out:
# C:\Users\joshu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.Average_Rating.describe()
# Out:
# count    21201.000000
# mean        13.882520
# std          0.916071
# min          0.000000
# 25%         13.600000
# 50%         14.000000
# 75%         14.300000
# max         15.200000
# Name: Average_Rating, dtype: float64

# %%
sns.displot(df.Average_Rating, bins=20, kde=False, rug=False)
# Out:
# C:\Users\joshu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.Average_Rating.value_counts()
# Out:
# Average_Rating
# 14.2    2766
# 14.1    2234
# 14.3    1939
# 13.7    1503
# 13.8    1427
# 14.0    1420
# 13.9     992
# 13.5     887
# 14.4     830
# 13.3     818
# 13.2     755
# 15.0     685
# 14.5     637
# 13.6     611
# 13.4     524
# 14.6     481
# 14.8     470
# 13.1     464
# 13.0     286
# 14.7     266
# 12.9     197
# 12.6     192
# 12.0     167
# 12.5     155
# 14.9     115
# 12.3     100
# 12.8      82
# 0.0       53
# 12.7      47
# 12.4      17
# 11.1      15
# 9.8       10
# 9.6        9
# 11.6       9
# 11.8       8
# 15.2       6
# 11.3       5
# 10.8       4
# 9.0        4
# 6.0        3
# 7.8        2
# 3.0        2
# 11.2       2
# 15.1       1
# 10.2       1
# Name: count, dtype: int64

# %%
df.No_of_Ratings.describe()
# Out:
# count    21201.000000
# mean       341.067119
# std        402.867746
# min          0.000000
# 25%         61.000000
# 50%        161.000000
# 75%        495.000000
# max       2298.000000
# Name: No_of_Ratings, dtype: float64

# %%
sns.scatterplot(x = df.No_of_Ratings, y = df.No_Of_Orders)
# Out:
# <Axes: xlabel='No_of_Ratings', ylabel='No_Of_Orders'>

# %%
df.dtypes
# Out:
# Rider_id           object
# No_Of_Orders        int64
# Age                 int64
# Average_Rating    float64
# No_of_Ratings       int64
# Platform_type       int64
# is_business          bool
# Pickup_weekday      int64
# Pickup_time         int64
# Distance            int64
# Temperature       float64
# Travel_time         int64
# dtype: object

# %%
df.Platform_type.value_counts()
# Out:
# Platform_type
# 3    18054
# 1     2147
# 2      980
# 4       20
# Name: count, dtype: int64

# %%
df['Platform_type'] = df['Platform_type'].astype('category')

# %%
df['Pickup_weekday'] = df['Pickup_weekday'].astype('category')

# %%
df.dtypes
# Out:
# Rider_id            object
# No_Of_Orders         int64
# Age                  int64
# Average_Rating     float64
# No_of_Ratings        int64
# Platform_type     category
# is_business           bool
# Pickup_weekday    category
# Pickup_time          int64
# Distance             int64
# Temperature        float64
# Travel_time          int64
# dtype: object

# %%
df.Pickup_time.describe()
# Out:
# count    21201.000000
# mean     48136.602660
# std       9131.670601
# min       2992.000000
# 25%      40682.000000
# 50%      47826.000000
# 75%      55384.000000
# max      83621.000000
# Name: Pickup_time, dtype: float64

# %%
sns.displot(df.Pickup_time, bins=20, kde=False, rug=False)
# Out:
# C:\Users\joshu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.Distance.describe()
# Out:
# count    21201.000000
# mean         9.506533
# std          5.668963
# min          1.000000
# 25%          5.000000
# 50%          8.000000
# 75%         13.000000
# max         49.000000
# Name: Distance, dtype: float64

# %%
sns.displot(df.Distance, bins=20, kde=False, rug=False)
# Out:
# C:\Users\joshu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.Temperature.describe()
# Out:
# count    21201.000000
# mean        23.258889
# std          3.222006
# min         11.200000
# 25%         21.400000
# 50%         23.258889
# 75%         25.300000
# max         32.100000
# Name: Temperature, dtype: float64

# %%
sns.displot(df.Temperature, bins=20, kde=False, rug=False)
# Out:
# C:\Users\joshu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.Temperature.value_counts()
# Out:
# Temperature
# 23.258889    4366
# 24.700000     201
# 22.400000     196
# 23.800000     195
# 23.700000     191
#              ...
# 13.900000       2
# 32.000000       2
# 14.000000       1
# 13.800000       1
# 11.200000       1
# Name: count, Length: 189, dtype: int64

# %%
df.Travel_time.describe()
# Out:
# count    21201.000000
# mean      1556.920947
# std        987.270788
# min          1.000000
# 25%        882.000000
# 50%       1369.000000
# 75%       2040.000000
# max       7883.000000
# Name: Travel_time, dtype: float64

# %%
sns.displot(df.Travel_time, bins=20, kde=False, rug=False)
# Out:
# C:\Users\joshu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.Travel_time.value_counts().head(25)
# Out:
# Travel_time
# 2       143
# 3        97
# 4        66
# 5        56
# 1        37
# 7        37
# 6        36
# 8        29
# 10       25
# 1424     24
# 9        21
# 1057     20
# 885      20
# 705      19
# 943      19
# 1097     19
# 1169     19
# 917      19
# 1142     19
# 1046     19
# 719      18
# 1093     18
# 1393     18
# 864      18
# 1207     18
# Name: count, dtype: int64

# %%
sns.scatterplot(x = df.Distance, y = df.Travel_time)
# Out:
# <Axes: xlabel='Distance', ylabel='Travel_time'>
